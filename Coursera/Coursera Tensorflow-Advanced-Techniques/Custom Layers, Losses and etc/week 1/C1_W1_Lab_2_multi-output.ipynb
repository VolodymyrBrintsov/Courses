# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 949us/sample - loss: 271.7646 - y1_output_loss: 126.3355 - y2_output_loss: 143.0338 - y1_output_root_mean_squared_error: 11.2929 - y2_output_root_mean_squared_error: 12.0098 - val_loss: 31.9360 - val_y1_output_loss: 12.8791 - val_y2_output_loss: 18.1352 - val_y1_output_root_mean_squared_error: 3.6298 - val_y2_output_root_mean_squared_error: 4.3313
# Epoch 2/500
# 614/614 [==============================] - 0s 142us/sample - loss: 30.3092 - y1_output_loss: 12.4162 - y2_output_loss: 17.7412 - y1_output_root_mean_squared_error: 3.5391 - y2_output_root_mean_squared_error: 4.2171 - val_loss: 39.5666 - val_y1_output_loss: 10.5857 - val_y2_output_loss: 28.5906 - val_y1_output_root_mean_squared_error: 3.2251 - val_y2_output_root_mean_squared_error: 5.4005
# Epoch 3/500
# 614/614 [==============================] - 0s 137us/sample - loss: 28.4275 - y1_output_loss: 11.0096 - y2_output_loss: 17.3236 - y1_output_root_mean_squared_error: 3.3287 - y2_output_root_mean_squared_error: 4.1650 - val_loss: 36.8416 - val_y1_output_loss: 13.4319 - val_y2_output_loss: 25.7237 - val_y1_output_root_mean_squared_error: 3.5363 - val_y2_output_root_mean_squared_error: 4.9331
# Epoch 4/500
# 614/614 [==============================] - 0s 143us/sample - loss: 26.4834 - y1_output_loss: 10.2467 - y2_output_loss: 16.3825 - y1_output_root_mean_squared_error: 3.1910 - y2_output_root_mean_squared_error: 4.0374 - val_loss: 60.8127 - val_y1_output_loss: 16.7554 - val_y2_output_loss: 43.1721 - val_y1_output_root_mean_squared_error: 4.0878 - val_y2_output_root_mean_squared_error: 6.6409
# Epoch 5/500
# 614/614 [==============================] - 0s 139us/sample - loss: 24.7587 - y1_output_loss: 9.5431 - y2_output_loss: 15.1029 - y1_output_root_mean_squared_error: 3.0868 - y2_output_root_mean_squared_error: 3.9026 - val_loss: 24.8637 - val_y1_output_loss: 9.1154 - val_y2_output_loss: 15.5793 - val_y1_output_root_mean_squared_error: 2.9947 - val_y2_output_root_mean_squared_error: 3.9870
# Epoch 6/500
# 614/614 [==============================] - 0s 146us/sample - loss: 21.2864 - y1_output_loss: 8.9847 - y2_output_loss: 12.3254 - y1_output_root_mean_squared_error: 2.9992 - y2_output_root_mean_squared_error: 3.5059 - val_loss: 19.1053 - val_y1_output_loss: 8.1382 - val_y2_output_loss: 11.9182 - val_y1_output_root_mean_squared_error: 2.7292 - val_y2_output_root_mean_squared_error: 3.4142
# Epoch 7/500
# 614/614 [==============================] - 0s 139us/sample - loss: 24.0853 - y1_output_loss: 9.3243 - y2_output_loss: 14.6020 - y1_output_root_mean_squared_error: 3.0651 - y2_output_root_mean_squared_error: 3.8328 - val_loss: 25.2486 - val_y1_output_loss: 10.2428 - val_y2_output_loss: 15.6037 - val_y1_output_root_mean_squared_error: 3.1186 - val_y2_output_root_mean_squared_error: 3.9399
# Epoch 8/500
# 614/614 [==============================] - 0s 139us/sample - loss: 28.1913 - y1_output_loss: 10.3648 - y2_output_loss: 18.0212 - y1_output_root_mean_squared_error: 3.2028 - y2_output_root_mean_squared_error: 4.2348 - val_loss: 35.9262 - val_y1_output_loss: 11.3483 - val_y2_output_loss: 27.6749 - val_y1_output_root_mean_squared_error: 3.1932 - val_y2_output_root_mean_squared_error: 5.0725
# Epoch 9/500
# 614/614 [==============================] - 0s 141us/sample - loss: 22.0654 - y1_output_loss: 8.9353 - y2_output_loss: 13.3188 - y1_output_root_mean_squared_error: 2.9884 - y2_output_root_mean_squared_error: 3.6242 - val_loss: 24.2439 - val_y1_output_loss: 8.4025 - val_y2_output_loss: 18.1135 - val_y1_output_root_mean_squared_error: 2.7266 - val_y2_output_root_mean_squared_error: 4.1000
# Epoch 10/500
# 614/614 [==============================] - 0s 154us/sample - loss: 23.8129 - y1_output_loss: 9.1647 - y2_output_loss: 14.6203 - y1_output_root_mean_squared_error: 3.0228 - y2_output_root_mean_squared_error: 3.8309 - val_loss: 17.6266 - val_y1_output_loss: 7.0119 - val_y2_output_loss: 11.1533 - val_y1_output_root_mean_squared_error: 2.5474 - val_y2_output_root_mean_squared_error: 3.3372
# Epoch 11/500
# 614/614 [==============================] - 0s 149us/sample - loss: 20.3806 - y1_output_loss: 8.1211 - y2_output_loss: 12.1739 - y1_output_root_mean_squared_error: 2.8571 - y2_output_root_mean_squared_error: 3.4954 - val_loss: 19.7883 - val_y1_output_loss: 8.1090 - val_y2_output_loss: 11.9084 - val_y1_output_root_mean_squared_error: 2.7944 - val_y2_output_root_mean_squared_error: 3.4611
# Epoch 12/500
# 614/614 [==============================] - 0s 144us/sample - loss: 20.8242 - y1_output_loss: 7.9023 - y2_output_loss: 12.7949 - y1_output_root_mean_squared_error: 2.8232 - y2_output_root_mean_squared_error: 3.5852 - val_loss: 23.0744 - val_y1_output_loss: 7.4562 - val_y2_output_loss: 15.8417 - val_y1_output_root_mean_squared_error: 2.6432 - val_y2_output_root_mean_squared_error: 4.0110
# Epoch 13/500
# 614/614 [==============================] - 0s 143us/sample - loss: 20.2187 - y1_output_loss: 7.7473 - y2_output_loss: 12.3956 - y1_output_root_mean_squared_error: 2.7916 - y2_output_root_mean_squared_error: 3.5251 - val_loss: 14.7919 - val_y1_output_loss: 6.9700 - val_y2_output_loss: 9.0734 - val_y1_output_root_mean_squared_error: 2.5006 - val_y2_output_root_mean_squared_error: 2.9222
# Epoch 14/500
# 614/614 [==============================] - 0s 144us/sample - loss: 19.3787 - y1_output_loss: 7.5628 - y2_output_loss: 11.6844 - y1_output_root_mean_squared_error: 2.7614 - y2_output_root_mean_squared_error: 3.4283 - val_loss: 16.9293 - val_y1_output_loss: 7.2457 - val_y2_output_loss: 10.1723 - val_y1_output_root_mean_squared_error: 2.6190 - val_y2_output_root_mean_squared_error: 3.1733
# Epoch 15/500
# 614/614 [==============================] - 0s 132us/sample - loss: 18.2507 - y1_output_loss: 7.2020 - y2_output_loss: 10.9441 - y1_output_root_mean_squared_error: 2.6914 - y2_output_root_mean_squared_error: 3.3177 - val_loss: 18.4416 - val_y1_output_loss: 7.5347 - val_y2_output_loss: 13.0301 - val_y1_output_root_mean_squared_error: 2.5660 - val_y2_output_root_mean_squared_error: 3.4435
# Epoch 16/500
# 614/614 [==============================] - 0s 136us/sample - loss: 20.0998 - y1_output_loss: 7.3526 - y2_output_loss: 13.0755 - y1_output_root_mean_squared_error: 2.6851 - y2_output_root_mean_squared_error: 3.5903 - val_loss: 32.3719 - val_y1_output_loss: 9.0399 - val_y2_output_loss: 22.8236 - val_y1_output_root_mean_squared_error: 2.9851 - val_y2_output_root_mean_squared_error: 4.8437
# Epoch 17/500
# 614/614 [==============================] - 0s 135us/sample - loss: 17.6382 - y1_output_loss: 6.8443 - y2_output_loss: 10.6584 - y1_output_root_mean_squared_error: 2.6268 - y2_output_root_mean_squared_error: 3.2769 - val_loss: 14.1302 - val_y1_output_loss: 5.9451 - val_y2_output_loss: 9.0083 - val_y1_output_root_mean_squared_error: 2.3060 - val_y2_output_root_mean_squared_error: 2.9686
# Epoch 18/500
# 614/614 [==============================] - 0s 135us/sample - loss: 15.7047 - y1_output_loss: 6.3306 - y2_output_loss: 9.4129 - y1_output_root_mean_squared_error: 2.5171 - y2_output_root_mean_squared_error: 3.0609 - val_loss: 14.6853 - val_y1_output_loss: 6.0689 - val_y2_output_loss: 9.0681 - val_y1_output_root_mean_squared_error: 2.3860 - val_y2_output_root_mean_squared_error: 2.9987
# Epoch 19/500
# 614/614 [==============================] - 0s 137us/sample - loss: 17.4154 - y1_output_loss: 6.6458 - y2_output_loss: 10.6094 - y1_output_root_mean_squared_error: 2.5902 - y2_output_root_mean_squared_error: 3.2721 - val_loss: 15.1010 - val_y1_output_loss: 6.4074 - val_y2_output_loss: 9.9216 - val_y1_output_root_mean_squared_error: 2.3389 - val_y2_output_root_mean_squared_error: 3.1033
# Epoch 20/500
# 614/614 [==============================] - 0s 133us/sample - loss: 16.7430 - y1_output_loss: 6.3309 - y2_output_loss: 10.2841 - y1_output_root_mean_squared_error: 2.5240 - y2_output_root_mean_squared_error: 3.2206 - val_loss: 13.7288 - val_y1_output_loss: 6.1296 - val_y2_output_loss: 8.5563 - val_y1_output_root_mean_squared_error: 2.3590 - val_y2_output_root_mean_squared_error: 2.8572
# Epoch 21/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.0596 - y1_output_loss: 5.7899 - y2_output_loss: 9.2353 - y1_output_root_mean_squared_error: 2.4079 - y2_output_root_mean_squared_error: 3.0433 - val_loss: 19.6730 - val_y1_output_loss: 6.7694 - val_y2_output_loss: 12.9183 - val_y1_output_root_mean_squared_error: 2.5470 - val_y2_output_root_mean_squared_error: 3.6312
# Epoch 22/500
# 614/614 [==============================] - 0s 146us/sample - loss: 17.7939 - y1_output_loss: 6.1719 - y2_output_loss: 11.4974 - y1_output_root_mean_squared_error: 2.4942 - y2_output_root_mean_squared_error: 3.4019 - val_loss: 13.1894 - val_y1_output_loss: 5.8096 - val_y2_output_loss: 8.1053 - val_y1_output_root_mean_squared_error: 2.3035 - val_y2_output_root_mean_squared_error: 2.8077
# Epoch 23/500
# 614/614 [==============================] - 0s 137us/sample - loss: 15.8261 - y1_output_loss: 5.6571 - y2_output_loss: 10.1304 - y1_output_root_mean_squared_error: 2.3847 - y2_output_root_mean_squared_error: 3.1842 - val_loss: 12.2198 - val_y1_output_loss: 5.4383 - val_y2_output_loss: 7.9487 - val_y1_output_root_mean_squared_error: 2.1510 - val_y2_output_root_mean_squared_error: 2.7555
# Epoch 24/500
# 614/614 [==============================] - 0s 140us/sample - loss: 14.3126 - y1_output_loss: 5.5625 - y2_output_loss: 8.7468 - y1_output_root_mean_squared_error: 2.3476 - y2_output_root_mean_squared_error: 2.9667 - val_loss: 12.5357 - val_y1_output_loss: 5.3866 - val_y2_output_loss: 7.6731 - val_y1_output_root_mean_squared_error: 2.2292 - val_y2_output_root_mean_squared_error: 2.7507
# Epoch 25/500
# 614/614 [==============================] - 0s 139us/sample - loss: 13.7273 - y1_output_loss: 5.2578 - y2_output_loss: 8.6305 - y1_output_root_mean_squared_error: 2.2587 - y2_output_root_mean_squared_error: 2.9370 - val_loss: 13.4825 - val_y1_output_loss: 4.7481 - val_y2_output_loss: 9.1325 - val_y1_output_root_mean_squared_error: 2.0654 - val_y2_output_root_mean_squared_error: 3.0359
# Epoch 26/500
# 614/614 [==============================] - 0s 146us/sample - loss: 13.6382 - y1_output_loss: 4.9113 - y2_output_loss: 8.6049 - y1_output_root_mean_squared_error: 2.2254 - y2_output_root_mean_squared_error: 2.9471 - val_loss: 11.2587 - val_y1_output_loss: 4.6278 - val_y2_output_loss: 7.0500 - val_y1_output_root_mean_squared_error: 2.0600 - val_y2_output_root_mean_squared_error: 2.6486
# Epoch 27/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.0507 - y1_output_loss: 4.8875 - y2_output_loss: 8.2749 - y1_output_root_mean_squared_error: 2.2030 - y2_output_root_mean_squared_error: 2.8632 - val_loss: 26.3632 - val_y1_output_loss: 9.6291 - val_y2_output_loss: 19.0678 - val_y1_output_root_mean_squared_error: 2.9499 - val_y2_output_root_mean_squared_error: 4.2025
# Epoch 28/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.7581 - y1_output_loss: 4.4360 - y2_output_loss: 7.2356 - y1_output_root_mean_squared_error: 2.1145 - y2_output_root_mean_squared_error: 2.6994 - val_loss: 11.7059 - val_y1_output_loss: 5.0366 - val_y2_output_loss: 8.1861 - val_y1_output_root_mean_squared_error: 2.0722 - val_y2_output_root_mean_squared_error: 2.7224
# Epoch 29/500
# 614/614 [==============================] - 0s 140us/sample - loss: 11.7278 - y1_output_loss: 4.2024 - y2_output_loss: 7.4321 - y1_output_root_mean_squared_error: 2.0569 - y2_output_root_mean_squared_error: 2.7381 - val_loss: 9.1086 - val_y1_output_loss: 4.2400 - val_y2_output_loss: 5.8250 - val_y1_output_root_mean_squared_error: 1.8910 - val_y2_output_root_mean_squared_error: 2.3522
# Epoch 30/500
# 614/614 [==============================] - 0s 135us/sample - loss: 13.7955 - y1_output_loss: 4.5366 - y2_output_loss: 9.1555 - y1_output_root_mean_squared_error: 2.1387 - y2_output_root_mean_squared_error: 3.0367 - val_loss: 8.7162 - val_y1_output_loss: 3.9305 - val_y2_output_loss: 5.4321 - val_y1_output_root_mean_squared_error: 1.8613 - val_y2_output_root_mean_squared_error: 2.2917
# Epoch 31/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.3554 - y1_output_loss: 3.8030 - y2_output_loss: 7.5450 - y1_output_root_mean_squared_error: 1.9557 - y2_output_root_mean_squared_error: 2.7442 - val_loss: 8.8991 - val_y1_output_loss: 4.4773 - val_y2_output_loss: 5.7764 - val_y1_output_root_mean_squared_error: 1.9324 - val_y2_output_root_mean_squared_error: 2.2727
# Epoch 32/500
# 614/614 [==============================] - 0s 138us/sample - loss: 9.2484 - y1_output_loss: 3.6068 - y2_output_loss: 5.6935 - y1_output_root_mean_squared_error: 1.9026 - y2_output_root_mean_squared_error: 2.3725 - val_loss: 12.9348 - val_y1_output_loss: 5.2656 - val_y2_output_loss: 8.0329 - val_y1_output_root_mean_squared_error: 2.2286 - val_y2_output_root_mean_squared_error: 2.8228
# Epoch 33/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.2905 - y1_output_loss: 3.7661 - y2_output_loss: 7.4902 - y1_output_root_mean_squared_error: 1.9422 - y2_output_root_mean_squared_error: 2.7420 - val_loss: 13.2001 - val_y1_output_loss: 5.0497 - val_y2_output_loss: 8.3018 - val_y1_output_root_mean_squared_error: 2.1878 - val_y2_output_root_mean_squared_error: 2.9006
# Epoch 34/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.7532 - y1_output_loss: 3.5496 - y2_output_loss: 6.3254 - y1_output_root_mean_squared_error: 1.8674 - y2_output_root_mean_squared_error: 2.5032 - val_loss: 36.6144 - val_y1_output_loss: 8.0462 - val_y2_output_loss: 27.9068 - val_y1_output_root_mean_squared_error: 2.8347 - val_y2_output_root_mean_squared_error: 5.3459
# Epoch 35/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.6497 - y1_output_loss: 3.1855 - y2_output_loss: 6.4108 - y1_output_root_mean_squared_error: 1.7836 - y2_output_root_mean_squared_error: 2.5433 - val_loss: 7.2982 - val_y1_output_loss: 3.0728 - val_y2_output_loss: 4.6998 - val_y1_output_root_mean_squared_error: 1.6409 - val_y2_output_root_mean_squared_error: 2.1461
# Epoch 36/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.9463 - y1_output_loss: 3.1067 - y2_output_loss: 5.8651 - y1_output_root_mean_squared_error: 1.7640 - y2_output_root_mean_squared_error: 2.4155 - val_loss: 8.8972 - val_y1_output_loss: 3.8310 - val_y2_output_loss: 5.4340 - val_y1_output_root_mean_squared_error: 1.8753 - val_y2_output_root_mean_squared_error: 2.3196
# Epoch 37/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.4511 - y1_output_loss: 3.1286 - y2_output_loss: 6.3091 - y1_output_root_mean_squared_error: 1.7695 - y2_output_root_mean_squared_error: 2.5140 - val_loss: 7.9013 - val_y1_output_loss: 3.5597 - val_y2_output_loss: 4.5798 - val_y1_output_root_mean_squared_error: 1.8314 - val_y2_output_root_mean_squared_error: 2.1324
# Epoch 38/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.9395 - y1_output_loss: 2.9832 - y2_output_loss: 5.9965 - y1_output_root_mean_squared_error: 1.7280 - y2_output_root_mean_squared_error: 2.4400 - val_loss: 15.0876 - val_y1_output_loss: 5.5509 - val_y2_output_loss: 9.6305 - val_y1_output_root_mean_squared_error: 2.3019 - val_y2_output_root_mean_squared_error: 3.1287
# Epoch 39/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.8451 - y1_output_loss: 2.5954 - y2_output_loss: 5.3792 - y1_output_root_mean_squared_error: 1.6142 - y2_output_root_mean_squared_error: 2.2890 - val_loss: 28.2194 - val_y1_output_loss: 6.7662 - val_y2_output_loss: 22.6681 - val_y1_output_root_mean_squared_error: 2.5035 - val_y2_output_root_mean_squared_error: 4.6853
# Epoch 40/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.3415 - y1_output_loss: 2.5512 - y2_output_loss: 5.7614 - y1_output_root_mean_squared_error: 1.6040 - y2_output_root_mean_squared_error: 2.4018 - val_loss: 7.6505 - val_y1_output_loss: 2.8873 - val_y2_output_loss: 5.3379 - val_y1_output_root_mean_squared_error: 1.6172 - val_y2_output_root_mean_squared_error: 2.2439
# Epoch 41/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.1889 - y1_output_loss: 3.1369 - y2_output_loss: 6.1063 - y1_output_root_mean_squared_error: 1.7524 - y2_output_root_mean_squared_error: 2.4734 - val_loss: 19.9528 - val_y1_output_loss: 5.7247 - val_y2_output_loss: 14.1951 - val_y1_output_root_mean_squared_error: 2.3443 - val_y2_output_root_mean_squared_error: 3.8022
# Epoch 42/500
# 614/614 [==============================] - 0s 137us/sample - loss: 10.4828 - y1_output_loss: 2.9730 - y2_output_loss: 7.4145 - y1_output_root_mean_squared_error: 1.7323 - y2_output_root_mean_squared_error: 2.7353 - val_loss: 6.4290 - val_y1_output_loss: 2.8903 - val_y2_output_loss: 3.9230 - val_y1_output_root_mean_squared_error: 1.6070 - val_y2_output_root_mean_squared_error: 1.9612
# Epoch 43/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.4712 - y1_output_loss: 2.2143 - y2_output_loss: 5.2586 - y1_output_root_mean_squared_error: 1.4859 - y2_output_root_mean_squared_error: 2.2942 - val_loss: 11.0154 - val_y1_output_loss: 2.8623 - val_y2_output_loss: 8.0865 - val_y1_output_root_mean_squared_error: 1.6524 - val_y2_output_root_mean_squared_error: 2.8784
# Epoch 44/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.6567 - y1_output_loss: 2.3592 - y2_output_loss: 5.2670 - y1_output_root_mean_squared_error: 1.5386 - y2_output_root_mean_squared_error: 2.2998 - val_loss: 8.3117 - val_y1_output_loss: 2.8729 - val_y2_output_loss: 5.9398 - val_y1_output_root_mean_squared_error: 1.6069 - val_y2_output_root_mean_squared_error: 2.3936
# Epoch 45/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.9519 - y1_output_loss: 2.4282 - y2_output_loss: 5.6755 - y1_output_root_mean_squared_error: 1.5434 - y2_output_root_mean_squared_error: 2.3600 - val_loss: 90.5228 - val_y1_output_loss: 24.2531 - val_y2_output_loss: 67.5178 - val_y1_output_root_mean_squared_error: 4.8760 - val_y2_output_root_mean_squared_error: 8.1699
# Epoch 46/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.5708 - y1_output_loss: 3.5474 - y2_output_loss: 6.9418 - y1_output_root_mean_squared_error: 1.8908 - y2_output_root_mean_squared_error: 2.6449 - val_loss: 6.8441 - val_y1_output_loss: 2.5442 - val_y2_output_loss: 4.4742 - val_y1_output_root_mean_squared_error: 1.5290 - val_y2_output_root_mean_squared_error: 2.1228
# Epoch 47/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.6378 - y1_output_loss: 2.0110 - y2_output_loss: 4.6191 - y1_output_root_mean_squared_error: 1.4212 - y2_output_root_mean_squared_error: 2.1489 - val_loss: 7.3358 - val_y1_output_loss: 2.7179 - val_y2_output_loss: 5.3736 - val_y1_output_root_mean_squared_error: 1.5220 - val_y2_output_root_mean_squared_error: 2.2403
# Epoch 48/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.7124 - y1_output_loss: 2.2927 - y2_output_loss: 5.4724 - y1_output_root_mean_squared_error: 1.5097 - y2_output_root_mean_squared_error: 2.3309 - val_loss: 8.4855 - val_y1_output_loss: 2.7153 - val_y2_output_loss: 6.4301 - val_y1_output_root_mean_squared_error: 1.5436 - val_y2_output_root_mean_squared_error: 2.4704
# Epoch 49/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.1485 - y1_output_loss: 2.5803 - y2_output_loss: 5.5379 - y1_output_root_mean_squared_error: 1.6039 - y2_output_root_mean_squared_error: 2.3613 - val_loss: 10.8541 - val_y1_output_loss: 2.8133 - val_y2_output_loss: 8.1578 - val_y1_output_root_mean_squared_error: 1.6012 - val_y2_output_root_mean_squared_error: 2.8793
# Epoch 50/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.3536 - y1_output_loss: 3.8825 - y2_output_loss: 8.3792 - y1_output_root_mean_squared_error: 1.9756 - y2_output_root_mean_squared_error: 2.9070 - val_loss: 8.3184 - val_y1_output_loss: 3.3350 - val_y2_output_loss: 5.4177 - val_y1_output_root_mean_squared_error: 1.7572 - val_y2_output_root_mean_squared_error: 2.2871
# Epoch 51/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.1005 - y1_output_loss: 1.9217 - y2_output_loss: 4.1362 - y1_output_root_mean_squared_error: 1.3916 - y2_output_root_mean_squared_error: 2.0406 - val_loss: 6.2794 - val_y1_output_loss: 2.7173 - val_y2_output_loss: 3.8276 - val_y1_output_root_mean_squared_error: 1.5733 - val_y2_output_root_mean_squared_error: 1.9504
# Epoch 52/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.5696 - y1_output_loss: 1.9680 - y2_output_loss: 4.5579 - y1_output_root_mean_squared_error: 1.4059 - y2_output_root_mean_squared_error: 2.1431 - val_loss: 7.5483 - val_y1_output_loss: 2.0645 - val_y2_output_loss: 5.6192 - val_y1_output_root_mean_squared_error: 1.3537 - val_y2_output_root_mean_squared_error: 2.3908
# Epoch 53/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.9102 - y1_output_loss: 1.7740 - y2_output_loss: 4.3440 - y1_output_root_mean_squared_error: 1.3065 - y2_output_root_mean_squared_error: 2.0502 - val_loss: 45.6553 - val_y1_output_loss: 13.8091 - val_y2_output_loss: 31.3589 - val_y1_output_root_mean_squared_error: 3.7113 - val_y2_output_root_mean_squared_error: 5.6464
# Epoch 54/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.4186 - y1_output_loss: 2.0361 - y2_output_loss: 5.3890 - y1_output_root_mean_squared_error: 1.4300 - y2_output_root_mean_squared_error: 2.3181 - val_loss: 7.2668 - val_y1_output_loss: 2.5442 - val_y2_output_loss: 5.1011 - val_y1_output_root_mean_squared_error: 1.5358 - val_y2_output_root_mean_squared_error: 2.2154
# Epoch 55/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.7618 - y1_output_loss: 2.5436 - y2_output_loss: 6.1915 - y1_output_root_mean_squared_error: 1.5877 - y2_output_root_mean_squared_error: 2.4982 - val_loss: 22.4262 - val_y1_output_loss: 9.0286 - val_y2_output_loss: 13.0569 - val_y1_output_root_mean_squared_error: 3.0036 - val_y2_output_root_mean_squared_error: 3.6612
# Epoch 56/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.5442 - y1_output_loss: 2.0485 - y2_output_loss: 4.4523 - y1_output_root_mean_squared_error: 1.4345 - y2_output_root_mean_squared_error: 2.1181 - val_loss: 5.3837 - val_y1_output_loss: 1.8626 - val_y2_output_loss: 3.5931 - val_y1_output_root_mean_squared_error: 1.3123 - val_y2_output_root_mean_squared_error: 1.9135
# Epoch 57/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.8145 - y1_output_loss: 1.8544 - y2_output_loss: 3.9822 - y1_output_root_mean_squared_error: 1.3516 - y2_output_root_mean_squared_error: 1.9969 - val_loss: 4.4759 - val_y1_output_loss: 1.8983 - val_y2_output_loss: 2.7984 - val_y1_output_root_mean_squared_error: 1.3052 - val_y2_output_root_mean_squared_error: 1.6650
# Epoch 58/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.1869 - y1_output_loss: 2.0678 - y2_output_loss: 5.0881 - y1_output_root_mean_squared_error: 1.4441 - y2_output_root_mean_squared_error: 2.2586 - val_loss: 13.1978 - val_y1_output_loss: 3.8760 - val_y2_output_loss: 9.8490 - val_y1_output_root_mean_squared_error: 1.9102 - val_y2_output_root_mean_squared_error: 3.0901
# Epoch 59/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.5603 - y1_output_loss: 1.6403 - y2_output_loss: 3.8815 - y1_output_root_mean_squared_error: 1.2822 - y2_output_root_mean_squared_error: 1.9790 - val_loss: 4.4267 - val_y1_output_loss: 1.7930 - val_y2_output_loss: 2.8055 - val_y1_output_root_mean_squared_error: 1.2793 - val_y2_output_root_mean_squared_error: 1.6704
# Epoch 60/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.0400 - y1_output_loss: 1.6881 - y2_output_loss: 4.3365 - y1_output_root_mean_squared_error: 1.3048 - y2_output_root_mean_squared_error: 2.0827 - val_loss: 7.9997 - val_y1_output_loss: 2.2690 - val_y2_output_loss: 6.0957 - val_y1_output_root_mean_squared_error: 1.4466 - val_y2_output_root_mean_squared_error: 2.4305
# Epoch 61/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.6648 - y1_output_loss: 1.6812 - y2_output_loss: 4.9463 - y1_output_root_mean_squared_error: 1.2976 - y2_output_root_mean_squared_error: 2.2318 - val_loss: 5.7452 - val_y1_output_loss: 2.3011 - val_y2_output_loss: 3.5996 - val_y1_output_root_mean_squared_error: 1.4816 - val_y2_output_root_mean_squared_error: 1.8842
# Epoch 62/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.8608 - y1_output_loss: 1.6603 - y2_output_loss: 4.1583 - y1_output_root_mean_squared_error: 1.2911 - y2_output_root_mean_squared_error: 2.0479 - val_loss: 5.0891 - val_y1_output_loss: 1.9826 - val_y2_output_loss: 3.4216 - val_y1_output_root_mean_squared_error: 1.3294 - val_y2_output_root_mean_squared_error: 1.8225
# Epoch 63/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.6431 - y1_output_loss: 1.6371 - y2_output_loss: 3.9929 - y1_output_root_mean_squared_error: 1.2843 - y2_output_root_mean_squared_error: 1.9984 - val_loss: 5.7311 - val_y1_output_loss: 1.5494 - val_y2_output_loss: 4.1751 - val_y1_output_root_mean_squared_error: 1.2015 - val_y2_output_root_mean_squared_error: 2.0706
# Epoch 64/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.4614 - y1_output_loss: 1.5016 - y2_output_loss: 3.9618 - y1_output_root_mean_squared_error: 1.2262 - y2_output_root_mean_squared_error: 1.9894 - val_loss: 3.9684 - val_y1_output_loss: 1.5414 - val_y2_output_loss: 2.7215 - val_y1_output_root_mean_squared_error: 1.1556 - val_y2_output_root_mean_squared_error: 1.6227
# Epoch 65/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.0651 - y1_output_loss: 1.4634 - y2_output_loss: 3.5769 - y1_output_root_mean_squared_error: 1.2075 - y2_output_root_mean_squared_error: 1.8993 - val_loss: 6.2944 - val_y1_output_loss: 1.8632 - val_y2_output_loss: 4.4410 - val_y1_output_root_mean_squared_error: 1.3219 - val_y2_output_root_mean_squared_error: 2.1324
# Epoch 66/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.9508 - y1_output_loss: 1.3319 - y2_output_loss: 3.6501 - y1_output_root_mean_squared_error: 1.1558 - y2_output_root_mean_squared_error: 1.9013 - val_loss: 5.4109 - val_y1_output_loss: 1.5862 - val_y2_output_loss: 3.8880 - val_y1_output_root_mean_squared_error: 1.1992 - val_y2_output_root_mean_squared_error: 1.9932
# Epoch 67/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.8035 - y1_output_loss: 1.6755 - y2_output_loss: 4.3265 - y1_output_root_mean_squared_error: 1.2965 - y2_output_root_mean_squared_error: 2.0304 - val_loss: 24.7906 - val_y1_output_loss: 5.1278 - val_y2_output_loss: 19.6837 - val_y1_output_root_mean_squared_error: 2.2637 - val_y2_output_root_mean_squared_error: 4.4347
# Epoch 68/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.5220 - y1_output_loss: 1.6463 - y2_output_loss: 4.8281 - y1_output_root_mean_squared_error: 1.2886 - y2_output_root_mean_squared_error: 2.2049 - val_loss: 3.9946 - val_y1_output_loss: 1.4606 - val_y2_output_loss: 2.5251 - val_y1_output_root_mean_squared_error: 1.1825 - val_y2_output_root_mean_squared_error: 1.6113
# Epoch 69/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.0515 - y1_output_loss: 1.9307 - y2_output_loss: 5.0862 - y1_output_root_mean_squared_error: 1.3898 - y2_output_root_mean_squared_error: 2.2627 - val_loss: 7.2225 - val_y1_output_loss: 3.3639 - val_y2_output_loss: 4.3293 - val_y1_output_root_mean_squared_error: 1.7469 - val_y2_output_root_mean_squared_error: 2.0422
# Epoch 70/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.5400 - y1_output_loss: 1.2716 - y2_output_loss: 3.2726 - y1_output_root_mean_squared_error: 1.1293 - y2_output_root_mean_squared_error: 1.8068 - val_loss: 5.1947 - val_y1_output_loss: 1.7070 - val_y2_output_loss: 3.6165 - val_y1_output_root_mean_squared_error: 1.2763 - val_y2_output_root_mean_squared_error: 1.8883
# Epoch 71/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.5116 - y1_output_loss: 1.2257 - y2_output_loss: 3.2838 - y1_output_root_mean_squared_error: 1.1079 - y2_output_root_mean_squared_error: 1.8123 - val_loss: 3.2151 - val_y1_output_loss: 1.2319 - val_y2_output_loss: 2.0245 - val_y1_output_root_mean_squared_error: 1.0730 - val_y2_output_root_mean_squared_error: 1.4366
# Epoch 72/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.7017 - y1_output_loss: 1.1671 - y2_output_loss: 3.5316 - y1_output_root_mean_squared_error: 1.0851 - y2_output_root_mean_squared_error: 1.8773 - val_loss: 3.0385 - val_y1_output_loss: 1.0305 - val_y2_output_loss: 2.0583 - val_y1_output_root_mean_squared_error: 0.9752 - val_y2_output_root_mean_squared_error: 1.4448
# Epoch 73/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.8009 - y1_output_loss: 0.9019 - y2_output_loss: 2.9378 - y1_output_root_mean_squared_error: 0.9531 - y2_output_root_mean_squared_error: 1.7007 - val_loss: 4.6238 - val_y1_output_loss: 0.8687 - val_y2_output_loss: 3.8758 - val_y1_output_root_mean_squared_error: 0.9029 - val_y2_output_root_mean_squared_error: 1.9515
# Epoch 74/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.1082 - y1_output_loss: 1.1424 - y2_output_loss: 3.9367 - y1_output_root_mean_squared_error: 1.0698 - y2_output_root_mean_squared_error: 1.9909 - val_loss: 3.0622 - val_y1_output_loss: 0.8173 - val_y2_output_loss: 2.3045 - val_y1_output_root_mean_squared_error: 0.8773 - val_y2_output_root_mean_squared_error: 1.5141
# Epoch 75/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.7903 - y1_output_loss: 1.0145 - y2_output_loss: 2.7802 - y1_output_root_mean_squared_error: 1.0065 - y2_output_root_mean_squared_error: 1.6665 - val_loss: 3.4939 - val_y1_output_loss: 1.1827 - val_y2_output_loss: 2.3323 - val_y1_output_root_mean_squared_error: 1.0568 - val_y2_output_root_mean_squared_error: 1.5418
# Epoch 76/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.9870 - y1_output_loss: 0.9547 - y2_output_loss: 3.0042 - y1_output_root_mean_squared_error: 0.9784 - y2_output_root_mean_squared_error: 1.7406 - val_loss: 4.8749 - val_y1_output_loss: 0.9255 - val_y2_output_loss: 3.8547 - val_y1_output_root_mean_squared_error: 0.9446 - val_y2_output_root_mean_squared_error: 1.9957
# Epoch 77/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.3776 - y1_output_loss: 1.0465 - y2_output_loss: 3.3390 - y1_output_root_mean_squared_error: 1.0249 - y2_output_root_mean_squared_error: 1.8241 - val_loss: 13.6732 - val_y1_output_loss: 3.7602 - val_y2_output_loss: 10.0821 - val_y1_output_root_mean_squared_error: 1.9296 - val_y2_output_root_mean_squared_error: 3.1543
# Epoch 78/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.3308 - y1_output_loss: 1.0208 - y2_output_loss: 3.3574 - y1_output_root_mean_squared_error: 1.0138 - y2_output_root_mean_squared_error: 1.8174 - val_loss: 8.8785 - val_y1_output_loss: 1.4516 - val_y2_output_loss: 7.2654 - val_y1_output_root_mean_squared_error: 1.1996 - val_y2_output_root_mean_squared_error: 2.7276
# Epoch 79/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8560 - y1_output_loss: 1.0312 - y2_output_loss: 2.8058 - y1_output_root_mean_squared_error: 1.0162 - y2_output_root_mean_squared_error: 1.6803 - val_loss: 3.2425 - val_y1_output_loss: 0.9107 - val_y2_output_loss: 2.4109 - val_y1_output_root_mean_squared_error: 0.9177 - val_y2_output_root_mean_squared_error: 1.5493
# Epoch 80/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.1334 - y1_output_loss: 0.7048 - y2_output_loss: 2.4130 - y1_output_root_mean_squared_error: 0.8421 - y2_output_root_mean_squared_error: 1.5570 - val_loss: 2.4695 - val_y1_output_loss: 0.7463 - val_y2_output_loss: 1.7810 - val_y1_output_root_mean_squared_error: 0.8306 - val_y2_output_root_mean_squared_error: 1.3340
# Epoch 81/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4464 - y1_output_loss: 0.9414 - y2_output_loss: 2.5088 - y1_output_root_mean_squared_error: 0.9607 - y2_output_root_mean_squared_error: 1.5885 - val_loss: 2.6750 - val_y1_output_loss: 0.7053 - val_y2_output_loss: 1.9424 - val_y1_output_root_mean_squared_error: 0.8165 - val_y2_output_root_mean_squared_error: 1.4172
# Epoch 82/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.9396 - y1_output_loss: 1.6748 - y2_output_loss: 4.2378 - y1_output_root_mean_squared_error: 1.2964 - y2_output_root_mean_squared_error: 2.0637 - val_loss: 4.5927 - val_y1_output_loss: 1.6588 - val_y2_output_loss: 2.9352 - val_y1_output_root_mean_squared_error: 1.2785 - val_y2_output_root_mean_squared_error: 1.7199
# Epoch 83/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.3041 - y1_output_loss: 0.7145 - y2_output_loss: 2.5666 - y1_output_root_mean_squared_error: 0.8477 - y2_output_root_mean_squared_error: 1.6079 - val_loss: 3.2101 - val_y1_output_loss: 0.9826 - val_y2_output_loss: 2.1921 - val_y1_output_root_mean_squared_error: 0.9724 - val_y2_output_root_mean_squared_error: 1.5048
# Epoch 84/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.0810 - y1_output_loss: 0.6675 - y2_output_loss: 2.4317 - y1_output_root_mean_squared_error: 0.8184 - y2_output_root_mean_squared_error: 1.5528 - val_loss: 3.0855 - val_y1_output_loss: 0.5921 - val_y2_output_loss: 2.4558 - val_y1_output_root_mean_squared_error: 0.7396 - val_y2_output_root_mean_squared_error: 1.5933
# Epoch 85/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7243 - y1_output_loss: 0.6426 - y2_output_loss: 2.1104 - y1_output_root_mean_squared_error: 0.8041 - y2_output_root_mean_squared_error: 1.4414 - val_loss: 6.2984 - val_y1_output_loss: 0.6236 - val_y2_output_loss: 5.5858 - val_y1_output_root_mean_squared_error: 0.7745 - val_y2_output_root_mean_squared_error: 2.3872
# Epoch 86/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.4810 - y1_output_loss: 1.2225 - y2_output_loss: 3.2234 - y1_output_root_mean_squared_error: 1.1107 - y2_output_root_mean_squared_error: 1.8020 - val_loss: 2.8121 - val_y1_output_loss: 0.8190 - val_y2_output_loss: 1.9601 - val_y1_output_root_mean_squared_error: 0.8957 - val_y2_output_root_mean_squared_error: 1.4177
# Epoch 87/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.0710 - y1_output_loss: 2.8843 - y2_output_loss: 7.1307 - y1_output_root_mean_squared_error: 1.7024 - y2_output_root_mean_squared_error: 2.6782 - val_loss: 7.3067 - val_y1_output_loss: 2.4912 - val_y2_output_loss: 4.6918 - val_y1_output_root_mean_squared_error: 1.5688 - val_y2_output_root_mean_squared_error: 2.2013
# Epoch 88/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.2051 - y1_output_loss: 0.7513 - y2_output_loss: 2.4274 - y1_output_root_mean_squared_error: 0.8696 - y2_output_root_mean_squared_error: 1.5649 - val_loss: 2.2866 - val_y1_output_loss: 0.5884 - val_y2_output_loss: 1.6898 - val_y1_output_root_mean_squared_error: 0.7421 - val_y2_output_root_mean_squared_error: 1.3176
# Epoch 89/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.0808 - y1_output_loss: 1.0069 - y2_output_loss: 3.0415 - y1_output_root_mean_squared_error: 1.0079 - y2_output_root_mean_squared_error: 1.7507 - val_loss: 6.5666 - val_y1_output_loss: 2.2081 - val_y2_output_loss: 4.3222 - val_y1_output_root_mean_squared_error: 1.4687 - val_y2_output_root_mean_squared_error: 2.0999
# Epoch 90/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.2502 - y1_output_loss: 0.8882 - y2_output_loss: 2.3553 - y1_output_root_mean_squared_error: 0.9447 - y2_output_root_mean_squared_error: 1.5355 - val_loss: 2.6357 - val_y1_output_loss: 0.8191 - val_y2_output_loss: 1.7743 - val_y1_output_root_mean_squared_error: 0.9019 - val_y2_output_root_mean_squared_error: 1.3499
# Epoch 91/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.5070 - y1_output_loss: 0.8309 - y2_output_loss: 2.6847 - y1_output_root_mean_squared_error: 0.9136 - y2_output_root_mean_squared_error: 1.6347 - val_loss: 4.2165 - val_y1_output_loss: 0.6508 - val_y2_output_loss: 3.5356 - val_y1_output_root_mean_squared_error: 0.7815 - val_y2_output_root_mean_squared_error: 1.8989
# Epoch 92/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.0020 - y1_output_loss: 0.6803 - y2_output_loss: 2.4079 - y1_output_root_mean_squared_error: 0.8258 - y2_output_root_mean_squared_error: 1.5232 - val_loss: 8.0553 - val_y1_output_loss: 1.4924 - val_y2_output_loss: 6.6339 - val_y1_output_root_mean_squared_error: 1.2111 - val_y2_output_root_mean_squared_error: 2.5668
# Epoch 93/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.4663 - y1_output_loss: 1.0772 - y2_output_loss: 3.3518 - y1_output_root_mean_squared_error: 1.0419 - y2_output_root_mean_squared_error: 1.8387 - val_loss: 2.0390 - val_y1_output_loss: 0.6068 - val_y2_output_loss: 1.4523 - val_y1_output_root_mean_squared_error: 0.7556 - val_y2_output_root_mean_squared_error: 1.2116
# Epoch 94/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.7444 - y1_output_loss: 1.7672 - y2_output_loss: 3.9276 - y1_output_root_mean_squared_error: 1.3348 - y2_output_root_mean_squared_error: 1.9906 - val_loss: 3.2412 - val_y1_output_loss: 0.8421 - val_y2_output_loss: 2.3290 - val_y1_output_root_mean_squared_error: 0.9118 - val_y2_output_root_mean_squared_error: 1.5524
# Epoch 95/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.8118 - y1_output_loss: 0.8988 - y2_output_loss: 2.8936 - y1_output_root_mean_squared_error: 0.9512 - y2_output_root_mean_squared_error: 1.7050 - val_loss: 3.3456 - val_y1_output_loss: 0.7953 - val_y2_output_loss: 2.5334 - val_y1_output_root_mean_squared_error: 0.8685 - val_y2_output_root_mean_squared_error: 1.6098
# Epoch 96/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.6320 - y1_output_loss: 0.6209 - y2_output_loss: 1.9993 - y1_output_root_mean_squared_error: 0.7903 - y2_output_root_mean_squared_error: 1.4168 - val_loss: 2.9077 - val_y1_output_loss: 0.5757 - val_y2_output_loss: 2.3466 - val_y1_output_root_mean_squared_error: 0.7487 - val_y2_output_root_mean_squared_error: 1.5320
# Epoch 97/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.3568 - y1_output_loss: 0.5196 - y2_output_loss: 1.8485 - y1_output_root_mean_squared_error: 0.7083 - y2_output_root_mean_squared_error: 1.3621 - val_loss: 2.9970 - val_y1_output_loss: 0.9905 - val_y2_output_loss: 1.9650 - val_y1_output_root_mean_squared_error: 1.0008 - val_y2_output_root_mean_squared_error: 1.4126
# Epoch 98/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.1558 - y1_output_loss: 0.7061 - y2_output_loss: 2.4253 - y1_output_root_mean_squared_error: 0.8438 - y2_output_root_mean_squared_error: 1.5633 - val_loss: 2.7048 - val_y1_output_loss: 0.8402 - val_y2_output_loss: 1.8312 - val_y1_output_root_mean_squared_error: 0.9097 - val_y2_output_root_mean_squared_error: 1.3701
# Epoch 99/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.8568 - y1_output_loss: 0.6638 - y2_output_loss: 2.2018 - y1_output_root_mean_squared_error: 0.8132 - y2_output_root_mean_squared_error: 1.4817 - val_loss: 3.5176 - val_y1_output_loss: 0.8520 - val_y2_output_loss: 2.6355 - val_y1_output_root_mean_squared_error: 0.9073 - val_y2_output_root_mean_squared_error: 1.6415
# Epoch 100/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.6999 - y1_output_loss: 0.6977 - y2_output_loss: 1.9879 - y1_output_root_mean_squared_error: 0.8373 - y2_output_root_mean_squared_error: 1.4138 - val_loss: 2.5504 - val_y1_output_loss: 0.7021 - val_y2_output_loss: 1.8054 - val_y1_output_root_mean_squared_error: 0.8317 - val_y2_output_root_mean_squared_error: 1.3633
# Epoch 101/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.0259 - y1_output_loss: 0.6586 - y2_output_loss: 2.3584 - y1_output_root_mean_squared_error: 0.8085 - y2_output_root_mean_squared_error: 1.5402 - val_loss: 2.0839 - val_y1_output_loss: 0.6008 - val_y2_output_loss: 1.4626 - val_y1_output_root_mean_squared_error: 0.7630 - val_y2_output_root_mean_squared_error: 1.2254
# Epoch 102/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.8324 - y1_output_loss: 0.6729 - y2_output_loss: 2.1441 - y1_output_root_mean_squared_error: 0.8218 - y2_output_root_mean_squared_error: 1.4687 - val_loss: 3.3875 - val_y1_output_loss: 0.7133 - val_y2_output_loss: 2.6501 - val_y1_output_root_mean_squared_error: 0.8373 - val_y2_output_root_mean_squared_error: 1.6390
# Epoch 103/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.1484 - y1_output_loss: 0.4953 - y2_output_loss: 1.6392 - y1_output_root_mean_squared_error: 0.7026 - y2_output_root_mean_squared_error: 1.2864 - val_loss: 2.0695 - val_y1_output_loss: 0.4635 - val_y2_output_loss: 1.5773 - val_y1_output_root_mean_squared_error: 0.6675 - val_y2_output_root_mean_squared_error: 1.2743
# Epoch 104/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8721 - y1_output_loss: 0.6077 - y2_output_loss: 2.2493 - y1_output_root_mean_squared_error: 0.7792 - y2_output_root_mean_squared_error: 1.5049 - val_loss: 2.1176 - val_y1_output_loss: 0.5625 - val_y2_output_loss: 1.5556 - val_y1_output_root_mean_squared_error: 0.7411 - val_y2_output_root_mean_squared_error: 1.2524
# Epoch 105/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.2951 - y1_output_loss: 0.8059 - y2_output_loss: 2.4947 - y1_output_root_mean_squared_error: 0.8960 - y2_output_root_mean_squared_error: 1.5787 - val_loss: 16.3426 - val_y1_output_loss: 3.7317 - val_y2_output_loss: 12.3717 - val_y1_output_root_mean_squared_error: 1.9417 - val_y2_output_root_mean_squared_error: 3.5458
# Epoch 106/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.5151 - y1_output_loss: 0.9451 - y2_output_loss: 2.6190 - y1_output_root_mean_squared_error: 0.9681 - y2_output_root_mean_squared_error: 1.6056 - val_loss: 3.8182 - val_y1_output_loss: 1.2264 - val_y2_output_loss: 2.5416 - val_y1_output_root_mean_squared_error: 1.1061 - val_y2_output_root_mean_squared_error: 1.6108
# Epoch 107/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.0421 - y1_output_loss: 0.9747 - y2_output_loss: 3.0364 - y1_output_root_mean_squared_error: 0.9910 - y2_output_root_mean_squared_error: 1.7493 - val_loss: 1.9623 - val_y1_output_loss: 0.4205 - val_y2_output_loss: 1.5229 - val_y1_output_root_mean_squared_error: 0.6403 - val_y2_output_root_mean_squared_error: 1.2460
# Epoch 108/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.9186 - y1_output_loss: 0.9527 - y2_output_loss: 2.9694 - y1_output_root_mean_squared_error: 0.9715 - y2_output_root_mean_squared_error: 1.7248 - val_loss: 8.6584 - val_y1_output_loss: 2.8731 - val_y2_output_loss: 5.5650 - val_y1_output_root_mean_squared_error: 1.7083 - val_y2_output_root_mean_squared_error: 2.3959
# Epoch 109/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.3025 - y1_output_loss: 0.5439 - y2_output_loss: 1.7695 - y1_output_root_mean_squared_error: 0.7368 - y2_output_root_mean_squared_error: 1.3265 - val_loss: 2.4484 - val_y1_output_loss: 0.7699 - val_y2_output_loss: 1.6307 - val_y1_output_root_mean_squared_error: 0.8857 - val_y2_output_root_mean_squared_error: 1.2899
# Epoch 110/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.8734 - y1_output_loss: 0.6706 - y2_output_loss: 2.1928 - y1_output_root_mean_squared_error: 0.8154 - y2_output_root_mean_squared_error: 1.4861 - val_loss: 2.4464 - val_y1_output_loss: 0.7030 - val_y2_output_loss: 1.7130 - val_y1_output_root_mean_squared_error: 0.8328 - val_y2_output_root_mean_squared_error: 1.3240
# Epoch 111/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.0049 - y1_output_loss: 0.4390 - y2_output_loss: 1.5565 - y1_output_root_mean_squared_error: 0.6643 - y2_output_root_mean_squared_error: 1.2504 - val_loss: 3.3193 - val_y1_output_loss: 1.1853 - val_y2_output_loss: 2.0894 - val_y1_output_root_mean_squared_error: 1.0877 - val_y2_output_root_mean_squared_error: 1.4616
# Epoch 112/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.4687 - y1_output_loss: 0.4988 - y2_output_loss: 1.9569 - y1_output_root_mean_squared_error: 0.7077 - y2_output_root_mean_squared_error: 1.4028 - val_loss: 2.1299 - val_y1_output_loss: 0.5090 - val_y2_output_loss: 1.6173 - val_y1_output_root_mean_squared_error: 0.7070 - val_y2_output_root_mean_squared_error: 1.2767
# Epoch 113/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.2185 - y1_output_loss: 0.5048 - y2_output_loss: 1.6995 - y1_output_root_mean_squared_error: 0.7102 - y2_output_root_mean_squared_error: 1.3092 - val_loss: 1.8904 - val_y1_output_loss: 0.4298 - val_y2_output_loss: 1.4570 - val_y1_output_root_mean_squared_error: 0.6460 - val_y2_output_root_mean_squared_error: 1.2137
# Epoch 114/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1022 - y1_output_loss: 0.7641 - y2_output_loss: 2.3152 - y1_output_root_mean_squared_error: 0.8754 - y2_output_root_mean_squared_error: 1.5283 - val_loss: 2.3622 - val_y1_output_loss: 0.6391 - val_y2_output_loss: 1.6772 - val_y1_output_root_mean_squared_error: 0.8012 - val_y2_output_root_mean_squared_error: 1.3116
# Epoch 115/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.2455 - y1_output_loss: 0.4623 - y2_output_loss: 1.8153 - y1_output_root_mean_squared_error: 0.6824 - y2_output_root_mean_squared_error: 1.3341 - val_loss: 11.0373 - val_y1_output_loss: 1.8038 - val_y2_output_loss: 9.2381 - val_y1_output_root_mean_squared_error: 1.3360 - val_y2_output_root_mean_squared_error: 3.0418
# Epoch 116/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.1027 - y1_output_loss: 0.4706 - y2_output_loss: 1.6252 - y1_output_root_mean_squared_error: 0.6853 - y2_output_root_mean_squared_error: 1.2779 - val_loss: 2.0826 - val_y1_output_loss: 0.5695 - val_y2_output_loss: 1.4848 - val_y1_output_root_mean_squared_error: 0.7598 - val_y2_output_root_mean_squared_error: 1.2269
# Epoch 117/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.2951 - y1_output_loss: 0.4964 - y2_output_loss: 1.7784 - y1_output_root_mean_squared_error: 0.7076 - y2_output_root_mean_squared_error: 1.3396 - val_loss: 2.0197 - val_y1_output_loss: 0.4861 - val_y2_output_loss: 1.5269 - val_y1_output_root_mean_squared_error: 0.6945 - val_y2_output_root_mean_squared_error: 1.2399
# Epoch 118/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.6382 - y1_output_loss: 0.5670 - y2_output_loss: 2.0585 - y1_output_root_mean_squared_error: 0.7483 - y2_output_root_mean_squared_error: 1.4416 - val_loss: 1.9656 - val_y1_output_loss: 0.5385 - val_y2_output_loss: 1.4259 - val_y1_output_root_mean_squared_error: 0.7339 - val_y2_output_root_mean_squared_error: 1.1946
# Epoch 119/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.9752 - y1_output_loss: 0.4627 - y2_output_loss: 1.4999 - y1_output_root_mean_squared_error: 0.6816 - y2_output_root_mean_squared_error: 1.2291 - val_loss: 4.0904 - val_y1_output_loss: 0.4391 - val_y2_output_loss: 3.6172 - val_y1_output_root_mean_squared_error: 0.6561 - val_y2_output_root_mean_squared_error: 1.9131
# Epoch 120/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.1013 - y1_output_loss: 0.7050 - y2_output_loss: 2.4262 - y1_output_root_mean_squared_error: 0.8318 - y2_output_root_mean_squared_error: 1.5522 - val_loss: 12.0507 - val_y1_output_loss: 2.3184 - val_y2_output_loss: 9.6401 - val_y1_output_root_mean_squared_error: 1.5296 - val_y2_output_root_mean_squared_error: 3.1163
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.6200 - y1_output_loss: 0.1513 - y2_output_loss: 0.4642 - y1_output_root_mean_squared_error: 0.3896 - y2_output_root_mean_squared_error: 0.6843 - val_loss: 0.8683 - val_y1_output_loss: 0.2066 - val_y2_output_loss: 0.6545 - val_y1_output_root_mean_squared_error: 0.4531 - val_y2_output_root_mean_squared_error: 0.8143
# Epoch 462/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4703 - y1_output_loss: 0.1312 - y2_output_loss: 0.3356 - y1_output_root_mean_squared_error: 0.3636 - y2_output_root_mean_squared_error: 0.5814 - val_loss: 0.8157 - val_y1_output_loss: 0.2421 - val_y2_output_loss: 0.6207 - val_y1_output_root_mean_squared_error: 0.4824 - val_y2_output_root_mean_squared_error: 0.7635
# Epoch 463/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4263 - y1_output_loss: 0.1138 - y2_output_loss: 0.3093 - y1_output_root_mean_squared_error: 0.3387 - y2_output_root_mean_squared_error: 0.5581 - val_loss: 0.7643 - val_y1_output_loss: 0.2155 - val_y2_output_loss: 0.5933 - val_y1_output_root_mean_squared_error: 0.4553 - val_y2_output_root_mean_squared_error: 0.7463
# Epoch 464/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4294 - y1_output_loss: 0.1261 - y2_output_loss: 0.3032 - y1_output_root_mean_squared_error: 0.3563 - y2_output_root_mean_squared_error: 0.5499 - val_loss: 1.1677 - val_y1_output_loss: 0.2156 - val_y2_output_loss: 0.9680 - val_y1_output_root_mean_squared_error: 0.4575 - val_y2_output_root_mean_squared_error: 0.9790
# Epoch 465/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3559 - y1_output_loss: 0.1164 - y2_output_loss: 0.2381 - y1_output_root_mean_squared_error: 0.3406 - y2_output_root_mean_squared_error: 0.4898 - val_loss: 0.7893 - val_y1_output_loss: 0.2482 - val_y2_output_loss: 0.5719 - val_y1_output_root_mean_squared_error: 0.4980 - val_y2_output_root_mean_squared_error: 0.7357
# Epoch 466/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4122 - y1_output_loss: 0.1358 - y2_output_loss: 0.2783 - y1_output_root_mean_squared_error: 0.3676 - y2_output_root_mean_squared_error: 0.5263 - val_loss: 0.9344 - val_y1_output_loss: 0.2324 - val_y2_output_loss: 0.7219 - val_y1_output_root_mean_squared_error: 0.4886 - val_y2_output_root_mean_squared_error: 0.8340
# Epoch 467/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4603 - y1_output_loss: 0.1177 - y2_output_loss: 0.3600 - y1_output_root_mean_squared_error: 0.3434 - y2_output_root_mean_squared_error: 0.5851 - val_loss: 4.2094 - val_y1_output_loss: 0.4995 - val_y2_output_loss: 3.6348 - val_y1_output_root_mean_squared_error: 0.7150 - val_y2_output_root_mean_squared_error: 1.9231
# Epoch 468/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5529 - y1_output_loss: 0.1471 - y2_output_loss: 0.4027 - y1_output_root_mean_squared_error: 0.3832 - y2_output_root_mean_squared_error: 0.6373 - val_loss: 0.8406 - val_y1_output_loss: 0.2994 - val_y2_output_loss: 0.5743 - val_y1_output_root_mean_squared_error: 0.5343 - val_y2_output_root_mean_squared_error: 0.7450
# Epoch 469/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3552 - y1_output_loss: 0.1147 - y2_output_loss: 0.2391 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.4900 - val_loss: 0.7160 - val_y1_output_loss: 0.2305 - val_y2_output_loss: 0.5064 - val_y1_output_root_mean_squared_error: 0.4753 - val_y2_output_root_mean_squared_error: 0.7001
# Epoch 470/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3569 - y1_output_loss: 0.1133 - y2_output_loss: 0.2430 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.4929 - val_loss: 0.8117 - val_y1_output_loss: 0.2348 - val_y2_output_loss: 0.6155 - val_y1_output_root_mean_squared_error: 0.4827 - val_y2_output_root_mean_squared_error: 0.7607
# Epoch 471/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5645 - y1_output_loss: 0.1635 - y2_output_loss: 0.3968 - y1_output_root_mean_squared_error: 0.4062 - y2_output_root_mean_squared_error: 0.6321 - val_loss: 0.7589 - val_y1_output_loss: 0.2436 - val_y2_output_loss: 0.5595 - val_y1_output_root_mean_squared_error: 0.4873 - val_y2_output_root_mean_squared_error: 0.7222
# Epoch 472/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4317 - y1_output_loss: 0.1219 - y2_output_loss: 0.3068 - y1_output_root_mean_squared_error: 0.3502 - y2_output_root_mean_squared_error: 0.5559 - val_loss: 0.8449 - val_y1_output_loss: 0.2684 - val_y2_output_loss: 0.5964 - val_y1_output_root_mean_squared_error: 0.5194 - val_y2_output_root_mean_squared_error: 0.7584
# Epoch 473/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4033 - y1_output_loss: 0.1173 - y2_output_loss: 0.2839 - y1_output_root_mean_squared_error: 0.3441 - y2_output_root_mean_squared_error: 0.5337 - val_loss: 0.7014 - val_y1_output_loss: 0.2159 - val_y2_output_loss: 0.5109 - val_y1_output_root_mean_squared_error: 0.4609 - val_y2_output_root_mean_squared_error: 0.6993
# Epoch 474/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5153 - y1_output_loss: 0.1588 - y2_output_loss: 0.3604 - y1_output_root_mean_squared_error: 0.3985 - y2_output_root_mean_squared_error: 0.5971 - val_loss: 0.8334 - val_y1_output_loss: 0.2625 - val_y2_output_loss: 0.5935 - val_y1_output_root_mean_squared_error: 0.5120 - val_y2_output_root_mean_squared_error: 0.7558
# Epoch 475/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4079 - y1_output_loss: 0.1158 - y2_output_loss: 0.2913 - y1_output_root_mean_squared_error: 0.3412 - y2_output_root_mean_squared_error: 0.5399 - val_loss: 0.9334 - val_y1_output_loss: 0.2319 - val_y2_output_loss: 0.7452 - val_y1_output_root_mean_squared_error: 0.4732 - val_y2_output_root_mean_squared_error: 0.8423
# Epoch 476/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5294 - y1_output_loss: 0.1407 - y2_output_loss: 0.3841 - y1_output_root_mean_squared_error: 0.3768 - y2_output_root_mean_squared_error: 0.6224 - val_loss: 0.8297 - val_y1_output_loss: 0.2497 - val_y2_output_loss: 0.6018 - val_y1_output_root_mean_squared_error: 0.4934 - val_y2_output_root_mean_squared_error: 0.7657
# Epoch 477/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3855 - y1_output_loss: 0.1197 - y2_output_loss: 0.2642 - y1_output_root_mean_squared_error: 0.3477 - y2_output_root_mean_squared_error: 0.5144 - val_loss: 0.7558 - val_y1_output_loss: 0.2397 - val_y2_output_loss: 0.5668 - val_y1_output_root_mean_squared_error: 0.4834 - val_y2_output_root_mean_squared_error: 0.7226
# Epoch 478/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4044 - y1_output_loss: 0.1346 - y2_output_loss: 0.2686 - y1_output_root_mean_squared_error: 0.3664 - y2_output_root_mean_squared_error: 0.5197 - val_loss: 0.9170 - val_y1_output_loss: 0.2748 - val_y2_output_loss: 0.6823 - val_y1_output_root_mean_squared_error: 0.5122 - val_y2_output_root_mean_squared_error: 0.8091
# Epoch 479/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4901 - y1_output_loss: 0.1420 - y2_output_loss: 0.3450 - y1_output_root_mean_squared_error: 0.3784 - y2_output_root_mean_squared_error: 0.5890 - val_loss: 0.7230 - val_y1_output_loss: 0.2210 - val_y2_output_loss: 0.5535 - val_y1_output_root_mean_squared_error: 0.4638 - val_y2_output_root_mean_squared_error: 0.7126
# Epoch 480/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4121 - y1_output_loss: 0.1260 - y2_output_loss: 0.2838 - y1_output_root_mean_squared_error: 0.3555 - y2_output_root_mean_squared_error: 0.5345 - val_loss: 0.7072 - val_y1_output_loss: 0.2476 - val_y2_output_loss: 0.4995 - val_y1_output_root_mean_squared_error: 0.4827 - val_y2_output_root_mean_squared_error: 0.6886
# Epoch 481/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.8539 - y1_output_loss: 0.1915 - y2_output_loss: 0.6577 - y1_output_root_mean_squared_error: 0.4394 - y2_output_root_mean_squared_error: 0.8129 - val_loss: 1.2527 - val_y1_output_loss: 0.2552 - val_y2_output_loss: 1.0201 - val_y1_output_root_mean_squared_error: 0.4950 - val_y2_output_root_mean_squared_error: 1.0038
# Epoch 482/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4816 - y1_output_loss: 0.1272 - y2_output_loss: 0.3552 - y1_output_root_mean_squared_error: 0.3549 - y2_output_root_mean_squared_error: 0.5963 - val_loss: 1.0208 - val_y1_output_loss: 0.4413 - val_y2_output_loss: 0.6309 - val_y1_output_root_mean_squared_error: 0.6548 - val_y2_output_root_mean_squared_error: 0.7694
# Epoch 483/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3692 - y1_output_loss: 0.1325 - y2_output_loss: 0.2352 - y1_output_root_mean_squared_error: 0.3637 - y2_output_root_mean_squared_error: 0.4868 - val_loss: 0.8453 - val_y1_output_loss: 0.2743 - val_y2_output_loss: 0.5758 - val_y1_output_root_mean_squared_error: 0.5283 - val_y2_output_root_mean_squared_error: 0.7525
# Epoch 484/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4537 - y1_output_loss: 0.1280 - y2_output_loss: 0.3379 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.5707 - val_loss: 2.4648 - val_y1_output_loss: 0.2628 - val_y2_output_loss: 2.1748 - val_y1_output_root_mean_squared_error: 0.5145 - val_y2_output_root_mean_squared_error: 1.4833
# Epoch 485/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4364 - y1_output_loss: 0.1231 - y2_output_loss: 0.3226 - y1_output_root_mean_squared_error: 0.3502 - y2_output_root_mean_squared_error: 0.5601 - val_loss: 2.5387 - val_y1_output_loss: 0.5889 - val_y2_output_loss: 1.9368 - val_y1_output_root_mean_squared_error: 0.7783 - val_y2_output_root_mean_squared_error: 1.3903
# Epoch 486/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4208 - y1_output_loss: 0.1387 - y2_output_loss: 0.2907 - y1_output_root_mean_squared_error: 0.3735 - y2_output_root_mean_squared_error: 0.5304 - val_loss: 2.7041 - val_y1_output_loss: 0.3686 - val_y2_output_loss: 2.4470 - val_y1_output_root_mean_squared_error: 0.5881 - val_y2_output_root_mean_squared_error: 1.5356
# Epoch 487/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4368 - y1_output_loss: 0.1214 - y2_output_loss: 0.3160 - y1_output_root_mean_squared_error: 0.3493 - y2_output_root_mean_squared_error: 0.5611 - val_loss: 0.9612 - val_y1_output_loss: 0.2679 - val_y2_output_loss: 0.7168 - val_y1_output_root_mean_squared_error: 0.5210 - val_y2_output_root_mean_squared_error: 0.8305
# Epoch 488/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4364 - y1_output_loss: 0.1217 - y2_output_loss: 0.3112 - y1_output_root_mean_squared_error: 0.3503 - y2_output_root_mean_squared_error: 0.5600 - val_loss: 0.7460 - val_y1_output_loss: 0.2448 - val_y2_output_loss: 0.5371 - val_y1_output_root_mean_squared_error: 0.4862 - val_y2_output_root_mean_squared_error: 0.7138
# Epoch 489/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4590 - y1_output_loss: 0.1224 - y2_output_loss: 0.3365 - y1_output_root_mean_squared_error: 0.3509 - y2_output_root_mean_squared_error: 0.5796 - val_loss: 0.8304 - val_y1_output_loss: 0.2287 - val_y2_output_loss: 0.6479 - val_y1_output_root_mean_squared_error: 0.4688 - val_y2_output_root_mean_squared_error: 0.7814
# Epoch 490/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3438 - y1_output_loss: 0.1034 - y2_output_loss: 0.2534 - y1_output_root_mean_squared_error: 0.3216 - y2_output_root_mean_squared_error: 0.4903 - val_loss: 1.6517 - val_y1_output_loss: 0.2634 - val_y2_output_loss: 1.4720 - val_y1_output_root_mean_squared_error: 0.5088 - val_y2_output_root_mean_squared_error: 1.1802
# Epoch 491/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5443 - y1_output_loss: 0.1412 - y2_output_loss: 0.4064 - y1_output_root_mean_squared_error: 0.3759 - y2_output_root_mean_squared_error: 0.6348 - val_loss: 1.8596 - val_y1_output_loss: 0.2854 - val_y2_output_loss: 1.6022 - val_y1_output_root_mean_squared_error: 0.5354 - val_y2_output_root_mean_squared_error: 1.2542
# Epoch 492/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3814 - y1_output_loss: 0.1039 - y2_output_loss: 0.2787 - y1_output_root_mean_squared_error: 0.3220 - y2_output_root_mean_squared_error: 0.5270 - val_loss: 0.9918 - val_y1_output_loss: 0.3190 - val_y2_output_loss: 0.6984 - val_y1_output_root_mean_squared_error: 0.5595 - val_y2_output_root_mean_squared_error: 0.8239
# Epoch 493/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3640 - y1_output_loss: 0.1162 - y2_output_loss: 0.2457 - y1_output_root_mean_squared_error: 0.3410 - y2_output_root_mean_squared_error: 0.4977 - val_loss: 0.7295 - val_y1_output_loss: 0.2465 - val_y2_output_loss: 0.5011 - val_y1_output_root_mean_squared_error: 0.4932 - val_y2_output_root_mean_squared_error: 0.6973
# Epoch 494/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5331 - y1_output_loss: 0.1422 - y2_output_loss: 0.3940 - y1_output_root_mean_squared_error: 0.3784 - y2_output_root_mean_squared_error: 0.6245 - val_loss: 1.8384 - val_y1_output_loss: 0.2379 - val_y2_output_loss: 1.6077 - val_y1_output_root_mean_squared_error: 0.4902 - val_y2_output_root_mean_squared_error: 1.2642
# Epoch 495/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4579 - y1_output_loss: 0.1182 - y2_output_loss: 0.3373 - y1_output_root_mean_squared_error: 0.3448 - y2_output_root_mean_squared_error: 0.5822 - val_loss: 0.7298 - val_y1_output_loss: 0.2435 - val_y2_output_loss: 0.5361 - val_y1_output_root_mean_squared_error: 0.4863 - val_y2_output_root_mean_squared_error: 0.7024
# Epoch 496/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3446 - y1_output_loss: 0.1133 - y2_output_loss: 0.2288 - y1_output_root_mean_squared_error: 0.3373 - y2_output_root_mean_squared_error: 0.4804 - val_loss: 0.7229 - val_y1_output_loss: 0.2388 - val_y2_output_loss: 0.5085 - val_y1_output_root_mean_squared_error: 0.4835 - val_y2_output_root_mean_squared_error: 0.6993
# Epoch 497/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3698 - y1_output_loss: 0.1201 - y2_output_loss: 0.2509 - y1_output_root_mean_squared_error: 0.3464 - y2_output_root_mean_squared_error: 0.4998 - val_loss: 1.2061 - val_y1_output_loss: 0.3555 - val_y2_output_loss: 0.9148 - val_y1_output_root_mean_squared_error: 0.5760 - val_y2_output_root_mean_squared_error: 0.9351
# Epoch 498/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3505 - y1_output_loss: 0.1202 - y2_output_loss: 0.2292 - y1_output_root_mean_squared_error: 0.3465 - y2_output_root_mean_squared_error: 0.4800 - val_loss: 0.7325 - val_y1_output_loss: 0.2159 - val_y2_output_loss: 0.5537 - val_y1_output_root_mean_squared_error: 0.4595 - val_y2_output_root_mean_squared_error: 0.7220
# Epoch 499/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4266 - y1_output_loss: 0.1144 - y2_output_loss: 0.3148 - y1_output_root_mean_squared_error: 0.3377 - y2_output_root_mean_squared_error: 0.5591 - val_loss: 0.8584 - val_y1_output_loss: 0.2194 - val_y2_output_loss: 0.6896 - val_y1_output_root_mean_squared_error: 0.4620 - val_y2_output_root_mean_squared_error: 0.8031
# Epoch 500/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3732 - y1_output_loss: 0.1235 - y2_output_loss: 0.2472 - y1_output_root_mean_squared_error: 0.3526 - y2_output_root_mean_squared_error: 0.4989 - val_loss: 0.6624 - val_y1_output_loss: 0.2111 - val_y2_output_loss: 0.4748 - val_y1_output_root_mean_squared_error: 0.4562 - val_y2_output_root_mean_squared_error: 0.6740

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 587us/sample - loss: 0.6624 - y1_output_loss: 0.2062 - y2_output_loss: 0.4585 - y1_output_root_mean_squared_error: 0.4562 - y2_output_root_mean_squared_error: 0.6740
# Loss = 0.6624279618263245, Y1_loss = 0.20624251663684845, Y1_mse = 0.4562206268310547, Y2_loss = 0.4585494101047516, Y2_mse = 0.6740109324455261

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
